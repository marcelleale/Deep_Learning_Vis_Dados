# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install matplotlib==3.5.2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 22.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 1.5.0 requires matplotlib>=3.7.1, but you have matplotlib 3.5.2 which is incompatible.
# plotnine 0.12.4 requires matplotlib>=3.6.0, but you have matplotlib 3.5.2 which is incompatible.
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
fig, ax = plt.subplots()
x = np.arange(0, 2*np.pi, 0.01)
line, = ax.plot(x, np.sin(x))


def animate(i):
  line.set_ydata(np.sin(x+i/10.0))
  return line,

def init():
  line.set_ydata(np.ma.array(x, mask=True))
  return line,

ani = animation.FuncAnimation(fig,animate,np.arange(1,200),init_func=init, interval = 25, blit = True)
plt.show()

# %% [markdown]
# A função *subplots* retorna a figura colocando quantos eixos eu quiser. Diferente do subplot.
#
# O default do subplots é (1,1) - uma linha e uma coluna.

# %% [markdown]
# **COMO CRIAR UMA FUNÇÃO EM PYTHON**
#
# def *nome_da_funcao* ():
#   print('Apenas um teste')
#
#   Os : é para ser usado quando não há argumentos.
#
# Chamada da função:
#
# nome_da_funcao()

# %%
def show():
  print('Apenas um teste')

show()
# Out:
# Apenas um teste

# %%
# !pip install matplotlib==3.5.2

# %%
# !pip install ipympl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 516.3/516.3 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 8.9 MB/s eta 0:00:00
# ...

# %%
# %matplotlib widget

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
fig, ax = plt.subplots()
x = np.arange(0, 2*np.pi, 0.01)
line, = ax.plot(x, np.sin(x))


def animate(i):
  line.set_ydata(np.sin(x+i/10.0))
  return line,

def init():
  line.set_ydata(np.ma.array(x, mask=True))
  return line,

ani = animation.FuncAnimation(fig,animate,np.arange(1,200),init_func=init, interval = 25, blit = True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# <ipython-input-29-f36d649065e9> in <cell line: 1>()
# ----> 1 fig, ax = plt.subplots()
#       2 x = np.arange(0, 2*np.pi, 0.01)
#       3 line, = ax.plot(x, np.sin(x))
#       4
#       5
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1499           C.E
#    1500           '''
# -> 1501
#    1502         where each character is a column and each line is a row.
#    1503         This only allows only single character Axes labels and does
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     452         # (signature.bind would fail, but the actual call would succeed).
#     453         if len(args) > name_idx:
# ...
