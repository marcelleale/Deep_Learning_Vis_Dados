# %%
import folium

# %%
mapa = folium.Map(location=[48.862140,  2.289971], zoom_start=50)
folium.TileLayer('cartodbdark_matter').add_to(mapa)
folium.Marker(
              [48.862140,  2.289971],
              tooltip = "Voilà",
              popup = "Torre Eiffel",
              icon = folium.Icon(color='red')
              ).add_to(mapa)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
from google.colab import drive
drive.mount('/content/MEU_DRIVE')
# Out:
# Mounted at /content/MEU_DRIVE

# %%
# !cp -R '/content/MEU_DRIVE/MyDrive/Visualização de Dados' '/content/Visualização de Dados'

# %%
folium.GeoJson(Limite_de_Bairros).add_to(mapa)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-5b7883de249b> in <cell line: 1>()
# ----> 1 folium.GeoJson(Limite_de_Bairros).add_to(mapa)
#
# NameError: name 'Limite_de_Bairros' is not defined
