# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ipython

# %%
import pandas as pd
import matplotlib.animation as animation
import matplotlib.pyplot as plt
from IPython.display import HTML
from IPython.display import Video

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Iris.csv', sep = ',')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
fig, ax = plt.subplots()
line, = ax.plot([], [], color = 'green', linestyle = 'dotted', markersize=5)

# %%
ax.set_xlim(df['SepalLengthCm'].min() - 1, df['SepalLengthCm'].max() + 1)
ax.set_ylim(df['SepalWidthCm'].min() - 1, df['SepalWidthCm'].max() + 1)
ax.set_xlabel('Sepal Length (cm)')
ax.set_ylabel('Sepal Width (cm)')
ax.set_title('Iris Sepal Length vs Sepal Width')
# Out:
# Text(0.5, 1.0, 'Iris Sepal Length vs Sepal Width')

# %%
def init():
    line.set_data([], [])
    return line,

# %%
def update(frame):
    x = df['SepalLengthCm'][:frame]
    y = df['SepalWidthCm'][:frame]
    line.set_data(x, y)
    return line,

# %%
ani = animation.FuncAnimation(fig, update, frames=len(df), init_func=init, blit=True, repeat=True)
HTML(ani.to_jshtml())
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
ani.save('/content/drive/MyDrive/Colab Notebooks/grafico_animado.mp4', writer='ffmpeg')

# %%
HTML('<video width="600" height="500" controls><source src="/content/drive/MyDrive/Colab Notebooks/grafico_animado.mp4" type="video/mp4"></video>')
# Out:
# <video width="600" height="500" controls><source src="/content/drive/MyDrive/Colab Notebooks/grafico_animado.mp4" type="video/mp4"></video>

# %%
Video('/content/drive/MyDrive/Colab Notebooks/grafico_animado.mp4', embed=True, html_attributes="loop autoplay")
# Out:
# <video loop autoplay  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
